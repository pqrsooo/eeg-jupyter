# %%
import csv

# from ls -1a
filenames = [
    'Aof-t20 (1024Hz)',
    'Aof-t21 (1024Hz)',
    'Aof-t22 (1024Hz)',
    'Aof-t23 (1024Hz)',
    'Aof-t24 (1024Hz)',
    'Aof-t25 (1024Hz)',
    'Beam-t1 (1024Hz)',
    'Beam-t2 (1024Hz)',
    'Beam-t3 (1024Hz)',
    'Beam-t6 (1024Hz)',
    'Beam-t7 (1024Hz)',
    'Beam-t8 (1024Hz)',
    'Donut-t1 (1024Hz)',
    'Donut-t2 (1024Hz)',
    'Donut-t3 (1024Hz)',
    'Donut-t4 (1024Hz)',
    'Donut-t5 (1024Hz)',
    'Donut-t6 (1024Hz)',
    'Donut-t7 (1024Hz)',
    'Eye-t1 (1024Hz)',
    'Eye-t2 (1024Hz)',
    'Eye-t3 (1024Hz)',
    'Eye-t4 (1024Hz)',
    'Eye-t5 (1024Hz)',
    'Eye-t6 (1024Hz)',
    'Eye-t7 (1024Hz)',
    'Faai-t1 (1024Hz)',
    'Faai-t2 (1024Hz)',
    'Faai-t3 (1024Hz)',
    'Faai-t4 (1024Hz)',
    'Faai-t5 (1024Hz)',
    'Faai-t6 (1024Hz)',
    'Fluke-t20 (1024Hz)',
    'Fluke-t21 (1024Hz)',
    'Fluke-t22 (1024Hz)',
    'Fluke-t23 (1024Hz)',
    'Fluke-t24 (1024Hz)',
    'Fluke-t25 (1024Hz)',
    'Fong-t1 (1024Hz)',
    'Fong-t2 (1024Hz)',
    'Fong-t3 (1024Hz)',
    'Fong-t4 (1024Hz)',
    'Fong-t5 (1024Hz)',
    'Fong-t6 (1024Hz)',
    'Fong-t7 (1024Hz)',
    'Fong-t8 (1024Hz)',
    'Joke-t1 (1024Hz)',
    'Joke-t2 (1024Hz)',
    'Joke-t3 (1024Hz)',
    'Joke-t4 (1024Hz)',
    'Joke-t5 (1024Hz)',
    'Joke-t6 (1024Hz)',
    'Pod-t20 (1024Hz)',
    'Pod-t21 (1024Hz)',
    'Pod-t22 (1024Hz)',
    'Pod-t23 (1024Hz)',
    'Pod-t24 (1024Hz)',
    'Pod-t25 (1024Hz)',
    'Pod-t26 (1024Hz)',
    'Tau-t11 (1024Hz)',
    'Tau-t13 (1024Hz)',
    'Tau-t14 (1024Hz)',
    'Tau-t15 (1024Hz)',
    'Tau-t16 (1024Hz)',
    'Tau-t17 (1024Hz)',
    'Tau-t18 (1024Hz)',
    'Toey-t1 (1024Hz)',
    'Toey-t2 (1024Hz)',
    'Toey-t3 (1024Hz)',
    'Toey-t4 (1024Hz)',
    'Toey-t5 (1024Hz)',
    'Toey-t6 (1024Hz)',
    'Toey-t7 (1024Hz)',
    'Tong-t1 (1024Hz)',
    'Tong-t2 (1024Hz)',
    'Tong-t3 (1024Hz)',
    'Tong-t4 (1024Hz)',
    'Tong-t5 (1024Hz)',
    'Tong-t6 (1024Hz)',
    'Torn-t1 (1024Hz)',
    'Torn-t2 (1024Hz)',
    'Torn-t3 (1024Hz)',
    'Torn-t4 (1024Hz)',
    'Torn-t5 (1024Hz)',
    'Torn-t6 (1024Hz)',
    'Torn-t7 (1024Hz)',
    'Torn-t8 (1024Hz)',
    'Torn-t9 (1024Hz)'
]

src_dir = './data/raw/'
dest_dir = './data/csv/'

infiles = [src_dir + s + '.txt' for s in filenames]
outfiles = [dest_dir + s + '.csv' for s in filenames]

# %%
for i in range(0, len(infiles)):
    print("Converting " + filenames[i])
    with open(infiles[i]) as fin, open(outfiles[i], 'w') as fout:
        o = csv.writer(fout)
        for line in fin:
            o.writerow(line.split())
        fin.close()
        fout.close()
print("Done.")
# Out:
# Converting Aof-t20 (1024Hz)
# Converting Aof-t21 (1024Hz)
# Converting Aof-t22 (1024Hz)
# Converting Aof-t23 (1024Hz)
# Converting Aof-t24 (1024Hz)
# Converting Aof-t25 (1024Hz)
# Converting Beam-t1 (1024Hz)
# Converting Beam-t2 (1024Hz)
# Converting Beam-t3 (1024Hz)
# Converting Beam-t6 (1024Hz)
# Converting Beam-t7 (1024Hz)
# Converting Beam-t8 (1024Hz)
# Converting Donut-t1 (1024Hz)
# Converting Donut-t2 (1024Hz)
# Converting Donut-t3 (1024Hz)
# Converting Donut-t4 (1024Hz)
# Converting Donut-t5 (1024Hz)
# Converting Donut-t6 (1024Hz)
# Converting Donut-t7 (1024Hz)
# Converting Eye-t1 (1024Hz)
# Converting Eye-t2 (1024Hz)
# Converting Eye-t3 (1024Hz)
# Converting Eye-t4 (1024Hz)
# Converting Eye-t5 (1024Hz)
# Converting Eye-t6 (1024Hz)
# Converting Eye-t7 (1024Hz)
# Converting Faai-t1 (1024Hz)
# Converting Faai-t2 (1024Hz)
# Converting Faai-t3 (1024Hz)
# Converting Faai-t4 (1024Hz)
# Converting Faai-t5 (1024Hz)
# Converting Faai-t6 (1024Hz)
# Converting Fluke-t20 (1024Hz)
# ...

# %%
import_str = ["import '!file-loader?name=[name].[ext]!./data/" + s + ".csv';" for s in filenames]
for s in import_str:
    print(s)
# Out:
# import '!file-loader?name=[name].[ext]!./data/Aof-t20 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Aof-t21 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Aof-t22 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Aof-t23 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Aof-t24 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Aof-t25 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t1 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t2 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t3 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t6 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t7 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Beam-t8 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Donut-t1 (1024Hz).csv';
# import '!file-loader?name=[name].[ext]!./data/Donut-t2 (1024Hz).csv';
# ...
